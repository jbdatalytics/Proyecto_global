# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

import sys 
sys.path.append('..')

from src import sp_cleaning as cl

# %%
df= pd.read_csv("../data/data_processed/transformacion.csv", low_memory=False)

# %%
cl.eda_preliminar(df)
# Out:
#          Category             City      Country Customer.ID   Customer.Name  \
# 22492   Furniture        Mejicanos  El Salvador   DP-130003   Darren Powers
# 29533  Technology             Kano      Nigeria    BD-15601  Brendan Dodson
# 43300  Technology  Rosny-sous-Bois       France   TS-213402   Toby Swindell
# 22520   Furniture          Managua    Nicaragua   JM-152653  Janet Molinari
#
#        Discount  Market  记录数               Order.Date         Order.ID  \
# 22492      0.00   LATAM    1  2012-04-18 00:00:00.000   MX-2012-146115
# 29533      0.70  Africa    1  2013-03-19 00:00:00.000     NI-2013-1560
# 43300      0.15      EU    1  2011-12-14 00:00:00.000  IT-2011-4264595
# 22520      0.00   LATAM    1  2014-05-05 00:00:00.000   MX-2014-108980
#
#       Order.Priority        Product.ID  \
# 22492         Medium   FUR-FU-10000110
# 29533         Medium  TEC-CIS-10003103
# 43300         Medium   TEC-PH-10003153
# 22520         Medium   FUR-FU-10002007
#
# ...

# %%
# Elimino columnas innecesarias
df = df.drop(columns=["记录数", "Market", "Customer.Name", "Region", "Row.ID", "Time Code", "Country Code"])

# %%
# Cambio el nombre de las columnas
df.columns = df.columns.str.replace(".", "_")
df.rename(columns={'Market2': 'Market', 'weeknum': 'Weeknum'}, inplace=True)

# %%
cl.convertir_col(df)

# %%
# Genero nuevas columnas a partir de Date
df['Month']= df['Order_Date'].dt.month    
df['Quarter']= df['Order_Date'].dt.quarter

# %%
df.sample(3)
# Out:
#               Category     City        Country Customer_ID  Discount  \
# 36579  Office Supplies   Kaduna        Nigeria    DR-28801       0.7
# 35514        Furniture  Caracas  Venezuela, RB   MK-179053       0.7
# 13004  Office Supplies  Jacareí         Brazil   JP-161353       0.0
#
#       Order_Date        Order_ID Order_Priority        Product_ID  \
# 36579 2014-03-18    NI-2014-4550           High  OFF-ADV-10001437
# 35514 2011-08-31  US-2011-158001           High   FUR-TA-10004972
# 13004 2013-11-06  MX-2013-111437         Medium   OFF-AR-10000019
#
#                              Product_Name   Profit  Quantity  Sales  \
# 36579     Advantus Paper Clips, Bulk Pack  -15.498         2      8
# 35514  Chromcraft Wood Table, Rectangular -819.376         8    768
# 13004              BIC Highlighters, Blue   15.480         3     38
#
#            Segment  Ship_Date       Ship_Mode  Shipping_Cost  \
# 36579    Corporate 2014-03-22  Standard Class          1.050
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51243 entries, 0 to 51242
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51243 non-null  object
#  1   City            51243 non-null  object
#  2   Country         51243 non-null  object
#  3   Customer_ID     51243 non-null  object
#  4   Discount        51243 non-null  float64
#  5   Order_Date      51243 non-null  datetime64[ns]
#  6   Order_ID        51243 non-null  object
#  7   Order_Priority  51243 non-null  object
#  8   Product_ID      51243 non-null  object
#  9   Product_Name    51243 non-null  object
#  10  Profit          51243 non-null  float64
#  11  Quantity        51243 non-null  int64
#  12  Sales           51243 non-null  int64
#  13  Segment         51243 non-null  object
#  14  Ship_Date       51243 non-null  datetime64[ns]
#  15  Ship_Mode       51243 non-null  object
# ...

# %%
# Guardo el archivo 

df.to_csv('../data/data_processed/limpieza.csv', index=False)
