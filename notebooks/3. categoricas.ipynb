# %%
import pandas as pd
import numpy as np

import sys 
sys.path.append('..')

from src import sp_cleaning as cl
from src import sp_visualizations as vis

# %%
df= pd.read_csv('../data/data_processed/limpieza.csv', parse_dates=['Order_Date', 'Ship_Date'])

# %%
numeros_nulos, porcentaje_nulos = cl.calcular_nulos(df)
porcentaje_nulos
# Out:
# Category          0.000000
# City              0.000000
# Country           0.000000
# Customer_ID       0.000000
# Discount          0.000000
# Order_Date        0.000000
# Order_ID          0.000000
# Order_Priority    0.000000
# Product_ID        0.000000
# Product_Name      0.000000
# Profit            0.000000
# Quantity          0.000000
# Sales             0.000000
# Segment           0.000000
# Ship_Date         0.000000
# Ship_Mode         0.000000
# Shipping_Cost     0.000000
# State             0.000000
# Sub_Category      0.000000
# Year              0.000000
# Market            0.000000
# Weeknum           0.000000
# Inflation(%)      2.328123
# Exports_GDP(%)    2.367153
# Imports_GDP(%)    2.367153
# GDP_Growth(%)     0.027321
# Month             0.000000
# Quarter           0.000000
# dtype: float64

# %%
cl.analisis_general_cat(df)
# Out:
# La distribución de la columna CATEGORY
# Esta columna tiene 3 valores únicos
# Category
# Office Supplies    0.609761
# Technology         0.197822
# Furniture          0.192417
# Name: proportion, dtype: float64
# --------------------
#  Describe
# count               51243
# unique                  3
# top       Office Supplies
# freq                31246
# Name: Category, dtype: object
# --------------------
# La distribución de la columna CITY
# Esta columna tiene 3633 valores únicos
# City
# New York City    0.017856
# Los Angeles      0.014578
# Philadelphia     0.010479
# San Francisco    0.009953
# Santo Domingo    0.008645
#                    ...
# Tinley Park      0.000020
# Champaign        0.000020
# Elyria           0.000020
# Littleton        0.000020
# Nagaoka          0.000020
# Name: proportion, Length: 3633, dtype: float64
# --------------------
#  Describe
# count             51243
# unique             3633
# top       New York City
# freq                915
# ...

# %%
df_cat= df[df.select_dtypes(include='O').columns]
df_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51243 entries, 0 to 51242
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        51243 non-null  object
#  1   City            51243 non-null  object
#  2   Country         51243 non-null  object
#  3   Customer_ID     51243 non-null  object
#  4   Order_ID        51243 non-null  object
#  5   Order_Priority  51243 non-null  object
#  6   Product_ID      51243 non-null  object
#  7   Product_Name    51243 non-null  object
#  8   Segment         51243 non-null  object
#  9   Ship_Mode       51243 non-null  object
#  10  State           51243 non-null  object
#  11  Sub_Category    51243 non-null  object
#  12  Market          51243 non-null  object
# dtypes: object(13)
# memory usage: 5.1+ MB

# %%
cl.calcular_nulos(df_cat)[1]
# Out:
# Category          0.0
# City              0.0
# Country           0.0
# Customer_ID       0.0
# Order_ID          0.0
# Order_Priority    0.0
# Product_ID        0.0
# Product_Name      0.0
# Segment           0.0
# Ship_Mode         0.0
# State             0.0
# Sub_Category      0.0
# Market            0.0
# dtype: float64

# %%
vis.subplot_col_cat(df,7)

# %%
# Guardo el archivo 

df.to_csv('../data/data_processed/nulos_cat.csv', index=False)
